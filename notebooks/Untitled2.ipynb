# %%
import re

d_str="????+??-??"

res = re.search(r"([0-9?]{4})[-.]([0-9?]{2})[.-]([0-9?]{2})", d_str)
if res:
    print (res.group(1))
    print (res.group(2))
    print (res.group(3))
else:
    print ("Mist!")
# Out:
# Mist!

# %%
# Out:
# 2001
